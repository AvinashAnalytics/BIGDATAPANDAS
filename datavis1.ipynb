# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car=pd.read_csv(r"C:\Users\Avinash rai\Downloads\cars-1.csv")

# %%
car.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
#  Generate a line plot graph for the column ‘model’ and ‘hp’:
#  a. Map the ‘model’ column on the x-axis
#  b. Map the ‘hp’ column on the y-axis
#  c. Provide the x-axis label as Models of the cars
#  d. Provide the y-axis label as Horse-Power of Cars
#  e. Set the title as Model Names vs HorsePower

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90) 
sns.lineplot(x='model',y='hp',data=car,marker='o')
plt.xlabel(' Models of the cars')
plt.ylabel('Horse-Power of Cars')
plt.title('Model Names vs Horsepower')
plt.tight_layout()

# %% [markdown]
# 1. Generate a bar plot graph for the columns ‘carbs’ and ‘gear’:
#  a. Map the ‘carbs’ onto the x-axis
#  b. Map the ‘gear’ onto the y-axis
#  c. Provide the x-axis label as Number of carburetors
#  d. Provide the y-axis label as Number of forward gears
#  e. Set the title as carbs vs gear
#  Contact us: support@intellipaat.com / © Copyright Intellipaat / All rights reserved
#  Inte li

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='carb',y='gear',data=car)
plt.xlabel('Number of carburetors')
plt.ylabel('Number of forward gears')
plt.title('carbs vs gear')
plt.show()

# %% [markdown]
#  Plot a histogram for the column ‘wt’:
#  a. Map the ‘wt’ onto the x-axis
#  b. Provide the x-axis label as ‘weight of the cars’
#  c. Provide the y-axis label as ‘Count’
#  d. Set the number of bins as 30
#  e. Set the title as ‘Histogram for the weight values

# %%
sns.histplot(car['wt'],bins=30,color='skyblue',edgecolor='black')
plt.xlabel('weight of the cars')
plt.ylabel('Count')
plt.title('Histogram for the weight values')
# Out:
# Text(0.5, 1.0, 'Histogram for the weight values')

# %% [markdown]
#  Plot a pie chart for columns: ‘cyl’ and ‘model’ form the mtcars.csv data
#  frame.

# %%
cyl_count = car['cyl'].value_counts()

# Plot the pie chart
plt.pie(cyl_count, labels=cyl_count.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'salmon'])
plt.title('Car Distribution by Cylinder Type')
# Out:
# Text(0.5, 1.0, 'Car Distribution by Cylinder Type')

# %% [markdown]
# 1. Plot the area chart for the columns ‘am’ and ‘carb’:
#  a. Set the ‘am’ on the x-axis
#  b. Set the ‘carb’ on the y-axis
#  c. Provide the x-axis label as Transmission
#  d. Provide the y-axis label as Number of carburetors
#  e. Provide the title as Transmission vs Number of carburetors

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x='am', y='carb', data=car, color='skyblue', linewidth=2)


plt.fill_between(car['am'], car['carb'], color='skyblue', alpha=0.6)


plt.xlabel('Transmission')
plt.ylabel('Number of carburetors')
plt.title('Transmission vs Number of carburetors')

plt.show()

# %%
import warnings

# Suppress the specific FutureWarning about `use_inf_as_na`
warnings.filterwarnings("ignore", message="use_inf_as_na option is deprecated")

# %%
import warnings

# Suppress all FutureWarnings globally
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd

# Replace infinity values with NaN in the `car` DataFrame
car.replace([float('inf'), -float('inf')], float('nan'), inplace=True)
